# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
from stats import median
import numpy as np

# %%
### Data Points
arr = np.array([2.3, 10.2,11.2, 12.3, 14.5, 14.6, 15.0, 15.1, 19.0, 24.0])

# %%
# Create box plot
fig1, ax1 = plt.subplots()
ax1.set_title('Basic Plot')
ax1.boxplot(arr)
# Out:
# <img src="data:image/png;base64,..." width="640">
# {'whiskers': [<matplotlib.lines.Line2D at 0x114438950>,
#   <matplotlib.lines.Line2D at 0x113a35810>],
#  'caps': [<matplotlib.lines.Line2D at 0x114447f10>,
#   <matplotlib.lines.Line2D at 0x1144387d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x114438910>],
#  'medians': [<matplotlib.lines.Line2D at 0x11445a990>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11445ae90>],
#  'means': []}
